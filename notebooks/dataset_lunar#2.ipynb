# %%
import pandas as pd
import datetime 
from astral.moon import phase

# %%
df = pd.read_csv(r"ETH-BTC.csv")

# %%
df["moon_phase"]=" "
df
# Out:
#             Date      Open      High       Low     Close  Adj Close    Volume  \
# 0     2017-11-10  0.044889  0.045845  0.044752  0.045217   0.045217  133872.0
# 1     2017-11-11  0.045116  0.050445  0.047089  0.049497   0.049497  132487.0
# 2     2017-11-12  0.049498  0.052312  0.053453  0.051749   0.051749  271170.0
# 3     2017-11-13  0.051600  0.054462  0.051703  0.048284   0.048284  158837.0
# 4     2017-11-14  0.048291  0.051687  0.048276  0.050881   0.050881  161200.0
# ...          ...       ...       ...       ...       ...        ...       ...
# 1896  2023-01-19  0.073240  0.073623  0.073198  0.073627   0.073627  305055.0
# 1897  2023-01-20  0.073618  0.073247  0.073706  0.073193   0.073193  376111.0
# 1898  2023-01-21  0.073190  0.072026  0.071428  0.071435   0.071435  388945.0
# 1899  2023-01-22  0.071446  0.072324  0.071890  0.071670   0.071670  330891.0
# 1900  2023-01-23  0.071633  0.072108  0.070960  0.070960   0.070960  348125.0
#
#      moon_phase
# 0
# 1
# 2
# 3
# ...

# %%
df['Date'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1901 entries, 0 to 1900
# Series name: Date
# Non-Null Count  Dtype
# --------------  -----
# 1901 non-null   object
# dtypes: object(1)
# memory usage: 15.0+ KB

# %%
df["Date"]=pd.to_datetime(df["Date"])

# %%
df['Date'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1901 entries, 0 to 1900
# Series name: Date
# Non-Null Count  Dtype
# --------------  -----
# 1901 non-null   datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 15.0 KB

# %%
for index, row in df.iterrows():
    date = row["Date"]
    phase_moon = phase(date)
    df.at[index, "moon_phase"] = phase_moon

df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 for index, row in df.iterrows():
#       2     date = row["Date"]
#       3     phase_moon = phase(date)
#
# NameError: name 'df' is not defined

# %%
def imprimir_fase(phase):
    if phase >=0 and phase <7:
        return "🌑 new moon"
    elif phase >= 7 and phase <14 :
        return "🌓 first quarter"
    elif phase >=14 and phase <21:
        return "🌕 full moon"
    elif phase >=21 and phase <28 :
        return "🌗 last quarter"
    else:
        return "Fase lunar desconocida."

# %%
df["name_phase"] = ""

for index, row in df.iterrows():
    phase = row["moon_phase"]
    name_phase = imprimir_fase(phase)
    df.at[index, "name_phase"] = name_phase

# %%
df
# Out:
#            Date      Open      High       Low     Close  Adj Close    Volume  \
# 0    2017-11-10  0.044889  0.045845  0.044752  0.045217   0.045217  133872.0
# 1    2017-11-11  0.045116  0.050445  0.047089  0.049497   0.049497  132487.0
# 2    2017-11-12  0.049498  0.052312  0.053453  0.051749   0.051749  271170.0
# 3    2017-11-13  0.051600  0.054462  0.051703  0.048284   0.048284  158837.0
# 4    2017-11-14  0.048291  0.051687  0.048276  0.050881   0.050881  161200.0
# ...         ...       ...       ...       ...       ...        ...       ...
# 1896 2023-01-19  0.073240  0.073623  0.073198  0.073627   0.073627  305055.0
# 1897 2023-01-20  0.073618  0.073247  0.073706  0.073193   0.073193  376111.0
# 1898 2023-01-21  0.073190  0.072026  0.071428  0.071435   0.071435  388945.0
# 1899 2023-01-22  0.071446  0.072324  0.071890  0.071670   0.071670  330891.0
# 1900 2023-01-23  0.071633  0.072108  0.070960  0.070960   0.070960  348125.0
#
#      moon_phase      name_phase
# ...

# %%
df[(df['moon_phase'] >= 14) & (df['moon_phase'] <21) ]
# Out:
#            Date      Open      High       Low     Close  Adj Close    Volume  \
#
# ...         ...       ...       ...       ...       ...        ...       ...
# 1896 2023-01-19  0.073240  0.073623  0.073198  0.073627   0.073627  305055.0
# 1897 2023-01-20  0.073618  0.073247  0.073706  0.073193   0.073193  376111.0
# 1898 2023-01-21  0.073190  0.072026  0.071428  0.071435   0.071435  388945.0
# 1899 2023-01-22  0.071446  0.072324  0.071890  0.071670   0.071670  330891.0
# 1900 2023-01-23  0.071633  0.072108  0.070960  0.070960   0.070960  348125.0
#
#      moon_phase      name_phase
# ...

# %%
df= df.drop(columns= 'Adj Close', axis=1)

# %%
df
# Out:
#            Date      Open      High       Low     Close    Volume moon_phase  \
# 0    2017-11-10  0.044889  0.045845  0.044752  0.045217  133872.0  20.566778
# 1    2017-11-11  0.045116  0.050445  0.047089  0.049497  132487.0  21.577889
# 2    2017-11-12  0.049498  0.052312  0.053453  0.051749  271170.0     22.589
# 3    2017-11-13  0.051600  0.054462  0.051703  0.048284  158837.0  23.522333
# 4    2017-11-14  0.048291  0.051687  0.048276  0.050881  161200.0  24.455667
# ...         ...       ...       ...       ...       ...       ...        ...
# 1896 2023-01-19  0.073240  0.073623  0.073198  0.073627  305055.0     25.389
# 1897 2023-01-20  0.073618  0.073247  0.073706  0.073193  376111.0  26.400111
# 1898 2023-01-21  0.073190  0.072026  0.071428  0.071435  388945.0     27.489
# 1899 2023-01-22  0.071446  0.072324  0.071890  0.071670  330891.0   0.577889
# 1900 2023-01-23  0.071633  0.072108  0.070960  0.070960  348125.0   1.744556
#
#           name_phase
# 0        🌕 full moon
# ...

# %%
df.insert(df.columns.get_loc('Close')+1, 'pct_change', df['Close'].pct_change())

# %%
df.columns= df.columns.str.lower()
df
# Out:
#            date      open      high       low     close  pct_change    volume  \
# 0    2017-11-10  0.044889  0.045845  0.044752  0.045217         NaN  133872.0
# 1    2017-11-11  0.045116  0.050445  0.047089  0.049497    0.094655  132487.0
# 2    2017-11-12  0.049498  0.052312  0.053453  0.051749    0.045498  271170.0
# 3    2017-11-13  0.051600  0.054462  0.051703  0.048284   -0.066958  158837.0
# 4    2017-11-14  0.048291  0.051687  0.048276  0.050881    0.053786  161200.0
# ...         ...       ...       ...       ...       ...         ...       ...
# 1896 2023-01-19  0.073240  0.073623  0.073198  0.073627    0.005106  305055.0
# 1897 2023-01-20  0.073618  0.073247  0.073706  0.073193   -0.005895  376111.0
# 1898 2023-01-21  0.073190  0.072026  0.071428  0.071435   -0.024019  388945.0
# 1899 2023-01-22  0.071446  0.072324  0.071890  0.071670    0.003290  330891.0
# 1900 2023-01-23  0.071633  0.072108  0.070960  0.070960   -0.009907  348125.0
#
#      moon_phase      name_phase
# ...
